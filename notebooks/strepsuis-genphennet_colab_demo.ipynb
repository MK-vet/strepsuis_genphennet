# %% [markdown]
# # strepsuis-genphennet - Google Colab Demonstration

# %%
# !pip install git+https://github.com/MK-vet/strepsuis-genphennet.git

# %%
# !strepsuis-genphennet --version

# %%
# !strepsuis-genphennet --help
